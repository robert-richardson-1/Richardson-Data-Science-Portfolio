# %% [markdown]
# # READ ME
# In this Jupyter Notebook, I will upload every visualization from every project that I complete
# - Visualizations will be ordered with the most recent project displayed first

# %% [markdown]
# ## Project 3: MLSreamlit App
#  - Example output of a Decision Tree model, with size = 0.2 and max depth = 4. Created using sample breast cancer dataset:
#
#
#  ![Screenshot 2026-04-14 152549.png](<attachment:Screenshot 2026-04-14 152549.png>)

# %% [markdown]
# ## Project 2: Tidy-Data Project
# - Horizontal bar chart that ranks the top 10 "X-Men" members by combined card value across all decades and markets:
#
#
# ![image.png](attachment:image.png)
#
# - A grouped bar chart by Decade that compares total card sales across all four markets from each decade:
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Project 1: Basic Streamlit App
# - Example of App's User Interface:
#
#
# ![Screenshot 2026-04-19 232002.png](<attachment:Screenshot 2026-04-19 232002.png>)
